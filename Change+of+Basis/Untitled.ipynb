# %%
import numpy as np

# %%
B2 = np.array([[1, 1],[2, 3]])
B2
# Out:
# array([[1, 1],
#        [2, 3]])

# %%
M = np.linalg.inv(B2)
M
# Out:
# array([[ 3., -1.],
#        [-2.,  1.]])

# %%
v1 = np.array([[4],[9]])

# %%
v2 = M@v1

# %%
v2
# Out:
# array([[3.],
#        [1.]])
